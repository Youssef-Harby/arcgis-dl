# %%
import warnings

import geopandas as gpd
import numpy as np
import pandas as pd
import requests
from arcgis2geojson import arcgis2geojson
from pkg_resources import packaging

# %%
GEOPANDAS_VERSION = packaging.version.parse(gpd.__version__)

# %%
def _get_json_safely(response):
    """
    Check for JSON response errors, and if all clear,
    return the JSON data
    """
    # bad status code
    if response.status_code != 200:
        response.raise_for_status()

    json = response.json()  # get the JSON
    if "error" in json:
        raise ValueError("Error: %s" % json["error"])

    return json

# %%
def get(url, fields=None, where=None, limit=None, **kwargs):
    """
    Scrape features from a ArcGIS Server REST API and return a
    geopandas GeoDataFrame.
    Parameters
    ----------
    url : str
        the REST API url for the Feature Service
    fields : list of str, optional
        the list of fields to include; the default behavior ('None')
        returns all fields
    where : str, optional
        a string specifying the selection clause to select a subset of
        data; the default behavior ('None') selects all data
    limit : int, optional
        limit the returned data to this many features
    Example
    -------
    >>> import esri2gpd
    >>> url = "https://services.arcgis.com/fLeGjb7u4uXqeF9q/arcgis/rest/services/Philadelphia_ZCTA_2018/FeatureServer/0"
    >>> gdf = esri2gpd.get(url, fields=['zip_code'], where="zip_code=19123")
    >>> gdf
    """
    # Get the max record count
    metadata = requests.get(url, params=dict(f="pjson")).json()
    max_record_count = metadata["maxRecordCount"]

    # default behavior matches all features
    if where is None:
        where = "1=1"
    if fields is None:
        fields = "*"
    else:
        fields = ", ".join(fields)

    # extract object IDs of features
    queryURL = f"{url}/query"

    # Get the total record count
    params = dict(where=where, returnCountOnly="true", f="json")
    response = requests.get(queryURL, params=params)
    total_size = _get_json_safely(response)["count"]

    # Check the limit
    if limit is not None:
        total_size = limit

    # params for this request
    resultOffset = 0
    params = dict(
        f="json",
        outSR="4326",
        outFields=fields,
        resultOffset=resultOffset,
        where=where,
        **kwargs,
    )

    calls = total_size // max_record_count
    if calls > 10:
        warnings.warn(
            f"Long download time — total download will require {calls} separate requests"
        )

    out = []
    while params["resultOffset"] < total_size:

        remaining = total_size - params["resultOffset"]
        if remaining < max_record_count:
            params["resultRecordCount"] = remaining

        # get raw features
        response = requests.get(queryURL, params=params)
        json = _get_json_safely(response)

        # convert to GeoJSON and save
        geojson = [arcgis2geojson(f) for f in json["features"]]
        if GEOPANDAS_VERSION >= packaging.version.parse("0.7"):
            gdf = gpd.GeoDataFrame.from_features(geojson, crs="EPSG:4326")
        else:
            gdf = gpd.GeoDataFrame.from_features(geojson, crs={"init": "epsg:4326"})
        out.append(gdf)

        params["resultOffset"] += len(out[-1])

    return pd.concat(out, axis=0).reset_index(drop=True)

# %%
url = "https://sampleserver6.arcgisonline.com/arcgis/rest/services/Energy/Geology/FeatureServer/1"

# %%
gdf = get(url)
# Out:
#                       geometry  objectid emp_id fold_type  \
# 0  POINT (-118.43530 34.45270)     20644  65321         1
# 1  POINT (-118.41444 34.44410)     20645  65321         2
# 2  POINT (-118.39896 34.50297)     20646  65321         2
# 3  POINT (-118.01166 34.58441)     20647   Tara         7
# 4  POINT (-118.42498 34.44223)     20648    123         1
# 5  POINT (-118.73210 34.33272)     20649   None        12
#
#   classification_confidence  strike   dip  dipdirection  plunge  trend  rake  \
# 0                         1   245.0  45.0           NaN     NaN    NaN   NaN
# 1                         2   165.0  84.0           NaN     NaN    NaN   NaN
# 2                         4   360.0  24.0           NaN     NaN    NaN   NaN
# 3                         4   180.0  45.0           0.0     0.0  180.0  45.0
# 4                      None     NaN   NaN           NaN     NaN    NaN   NaN
# 5                      None     NaN   NaN           NaN     NaN    NaN   NaN
#
#   measurement_confidence method_measurement  \
# 0                      2                  1
# 1                      4                  2
# 2                      1                  4
# 3                      3               None
# 4                   None               None
# 5                   None               None
#
#                                  globalid                       comments photo
# 0  {0560DB5A-0AFF-4421-8992-F8E46CFF6761}                           None  None
# 1  {FEA1E1B1-B032-4AFD-ADAE-AADCEEA30CA6}                           None  None
# 2  {3A8E2190-76ED-4D08-B1E4-1A354C33F4F8}                           None  None
# 3  {975C5554-5AF6-4758-AD22-BDF7A45EC19F}  This could be a mistake fold   None
# 4  {6CF954C6-5DBA-4FAC-910B-BD728CD2D801}                           None  None
# 5  {43EF1E29-52F1-40B1-8415-4EB76C70AD79}                           None  None

# %%
metadata = requests.get(url, params=dict(f="pjson")).json()
metadata
# Out:
# {'currentVersion': 10.71,
#  'id': 1,
#  'name': 'Fold (Point)',
#  'type': 'Feature Layer',
#  'parentLayer': None,
#  'defaultVisibility': True,
#  'minScale': 0,
#  'maxScale': 0,
#  'geometryType': 'esriGeometryPoint',
#  'description': '',
#  'copyrightText': '',
#  'editFieldsInfo': None,
#  'ownershipBasedAccessControlForFeatures': None,
#  'syncCanReturnChanges': False,
#  'relationships': [],
#  'isDataVersioned': False,
#  'isDataArchived': False,
#  'isCoGoEnabled': False,
#  'supportsRollbackOnFailureParameter': False,
#  'archivingInfo': {'supportsQueryWithHistoricMoment': False,
#   'startArchivingMoment': -1},
#  'supportsStatistics': True,
#  'supportsAdvancedQueries': True,
#  'supportsValidateSQL': True,
#  'supportsCoordinatesQuantization': True,
#  'supportsCalculate': True,
#  'advancedQueryCapabilities': {'supportsPagination': True,
#   'supportsTrueCurve': True,
#   'supportsQueryWithDistance': True,
#   'supportsReturningQueryExtent': True,
#   'supportsStatistics': True,
#   'supportsHavingClause': True,
#   'supportsOrderBy': True,
#   'supportsDistinct': True,
#   'supportsCountDistinct': True,
#   'supportsQueryWithResultType': True,
#   'supportsReturningGeometryCentroid': False,
#   'supportsSqlExpression': True},
#  'extent': {'xmin': -13217197.1552,
#   'ymin': 4073565.805399999,
#   'xmax': -13136998.1139,
#   'ymax': 4107546.0627000034,
#   'spatialReference': {'wkid': 102100, 'latestWkid': 3857}},
#  'sourceSpatialReference': {'wkid': 102100, 'latestWkid': 3857},
#  'drawingInfo': {'renderer': {'type': 'uniqueValue',
#    'field1': 'fold_type',
#    'field2': None,
#    'field3': None,
#    'defaultSymbol': None,
#    'defaultLabel': None,
#    'uniqueValueInfos': [{'symbol': {'type': 'esriPMS',
#       'url': '1a41edf75bfd6dc8a31edc18453b9365',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 14,
#       'height': 17,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '1',
#      'label': 'Anticline',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': '5fbd0e5e785bae77bb4c35cf76d8084b',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 17,
#       'height': 20,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '7',
#      'label': 'Antiform',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': '12958dae40f01db75c20f03824976148',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 19,
#       'height': 10,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '12',
#      'label': 'Asymmetrical Anticline',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': '4abcc5060a0965c550f284d3459ce3c8',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 19,
#       'height': 10,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '13',
#      'label': 'Asymmetrical Syncline',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': 'ec05fd0a90bc27ed5b226afd590b6437',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 10,
#       'height': 10,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '20',
#      'label': 'Fold Axis, fodl type unknown or indeterminable',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': '7ec60756a328c5544fbfb69f327343e6',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 9,
#       'height': 9,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '15',
#      'label': 'Fold Hinge Length Exposed at surface',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': 'e0abe79da2f6419f9d08b75cfcef305f',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 10,
#       'height': 10,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '16',
#      'label': 'Hinge Line',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': '8741b9a40501ea78026da27187856d27',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 13,
#       'height': 18,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '14',
#      'label': 'Monocline',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': '3e0bdf2814252229298a2b473e5bd840',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 25,
#       'height': 25,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '5',
#      'label': 'Monocline, Anticlinal Bend',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': '4f18de3d4c901b64811981c814db42cf',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 17,
#       'height': 22,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '6',
#      'label': 'Monocline, Synclinal Bend',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': '21aaa413cdaa28fbab53b716e79bc95e',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 12,
#       'height': 19,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '3',
#      'label': 'Overturned Anticline',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': 'eeb5e201753b70a0040814d605f9f3f6',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 12,
#       'height': 19,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '9',
#      'label': 'Overturned Antiform',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': '14862342319015c932e390d70de10a33',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 12,
#       'height': 19,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '4',
#      'label': 'Overturned Syncline',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': '14862342319015c932e390d70de10a33',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 12,
#       'height': 19,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '10',
#      'label': 'Overturned Synform',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': '15c96e869f3ccf1cf87d89828ff9d5a5',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 16,
#       'height': 19,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '2',
#      'label': 'Syncline',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': '1b5cf9e2c464b54d28241553290e4255',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 16,
#       'height': 19,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '8',
#      'label': 'Synform',
#      'description': ''},
#     {'symbol': {'type': 'esriPMS',
#       'url': 'd530b7e6f1968fbe49c17f398707dcbc',
#       'imageData': '...',
#       'contentType': 'image/png',
#       'width': 3,
#       'height': 21,
#       'angle': 0,
#       'xoffset': 0,
#       'yoffset': 0},
#      'value': '21',
#      'label': 'Trace of Axial Surface',
#      'description': ''}],
#    'fieldDelimiter': ','},
#   'transparency': 0,
#   'labelingInfo': None},
#  'hasM': False,
#  'hasZ': False,
#  'allowGeometryUpdates': True,
#  'allowTrueCurvesUpdates': False,
#  'onlyAllowTrueCurveUpdatesByTrueCurveClients': True,
#  'hasAttachments': True,
#  'supportsAttachmentsByUploadId': True,
#  'supportsApplyEditsWithGlobalIds': False,
#  'htmlPopupType': 'esriServerHTMLPopupTypeAsHTMLText',
#  'objectIdField': 'objectid',
#  'globalIdField': 'globalid',
#  'displayField': 'emp_id',
#  'typeIdField': 'fold_type',
#  'subtypeField': '',
#  'fields': [{'name': 'objectid',
#    'type': 'esriFieldTypeOID',
#    'alias': 'OBJECTID',
#    'domain': None,
#    'editable': False,
#    'nullable': False,
#    'defaultValue': None,
#    'modelName': 'OBJECTID'},
#   {'name': 'emp_id',
#    'type': 'esriFieldTypeString',
#    'alias': 'Employee ID',
#    'domain': None,
#    'editable': True,
#    'nullable': True,
#    'length': 10,
#    'defaultValue': None,
#    'modelName': 'Emp_ID'},
#   {'name': 'fold_type',
#    'type': 'esriFieldTypeString',
#    'alias': 'Fold Type',
#    'domain': {'type': 'codedValue',
#     'name': 'Fold_Type_1',
#     'description': 'Type of fold',
#     'codedValues': [{'name': 'Anticline', 'code': '1'},
#      {'name': 'Syncline', 'code': '2'},
#      {'name': 'Overturned Anticline', 'code': '3'},
#      {'name': 'Overturned Syncline', 'code': '4'},
#      {'name': 'Monocline, Anticlinal Bend', 'code': '5'},
#      {'name': 'Monocline, Synclinal Bend', 'code': '6'},
#      {'name': 'Antiform', 'code': '7'},
#      {'name': 'Synform', 'code': '8'},
#      {'name': 'Overturned Antiform', 'code': '9'},
#      {'name': 'Overturned Synform', 'code': '10'},
#      {'name': 'Asymmetrical Anticline', 'code': '12'},
#      {'name': 'Asymmetrical Syncline', 'code': '13'},
#      {'name': 'Monocline', 'code': '14'},
#      {'name': 'Fold Hinge Length Exposed at surface', 'code': '15'},
#      {'name': 'Hinge Line', 'code': '16'},
#      {'name': 'Fold Axis, fodl type unknown or indeterminable', 'code': '20'},
#      {'name': 'Trace of Axial Surface', 'code': '21'}],
#     'mergePolicy': 'esriMPTDefaultValue',
#     'splitPolicy': 'esriSPTDefaultValue'},
#    'editable': True,
#    'nullable': True,
#    'length': 50,
#    'defaultValue': None,
#    'modelName': 'Fold_Type'},
#   {'name': 'classification_confidence',
#    'type': 'esriFieldTypeString',
#    'alias': 'Confidence in Classification',
#    'domain': {'type': 'codedValue',
#     'name': 'IDConf',
#     'description': 'Confidence in IDing the litho',
#     'codedValues': [{'name': 'Unspecified', 'code': '1'},
#      {'name': 'Uncertain', 'code': '2'},
#      {'name': 'Fairly Certain', 'code': '3'},
#      {'name': 'Absolute Certainty', 'code': '4'}],
#     'mergePolicy': 'esriMPTDefaultValue',
#     'splitPolicy': 'esriSPTDefaultValue'},
#    'editable': True,
#    'nullable': True,
#    'length': 10,
#    'defaultValue': None,
#    'modelName': 'Classification_Confidence'},
#   {'name': 'strike',
#    'type': 'esriFieldTypeSmallInteger',
#    'alias': 'Strike',
#    'domain': {'type': 'range',
#     'name': 'ShorStrike',
#     'description': 'Short range strike',
#     'range': [0, 360],
#     'mergePolicy': 'esriMPTDefaultValue',
#     'splitPolicy': 'esriSPTDefaultValue'},
#    'editable': True,
#    'nullable': True,
#    'defaultValue': None,
#    'modelName': 'Strike'},
#   {'name': 'dip',
#    'type': 'esriFieldTypeSmallInteger',
#    'alias': 'Dip',
#    'domain': {'type': 'range',
#     'name': 'ShorRange',
#     'description': 'Range for dip',
#     'range': [-90, 90],
#     'mergePolicy': 'esriMPTDefaultValue',
#     'splitPolicy': 'esriSPTDefaultValue'},
#    'editable': True,
#    'nullable': True,
#    'defaultValue': None,
#    'modelName': 'Dip'},
#   {'name': 'dipdirection',
#    'type': 'esriFieldTypeSmallInteger',
#    'alias': 'DipDirection',
#    'domain': {'type': 'range',
#     'name': 'ShorRange',
#     'description': 'Range for dip',
#     'range': [-90, 90],
#     'mergePolicy': 'esriMPTDefaultValue',
#     'splitPolicy': 'esriSPTDefaultValue'},
#    'editable': True,
#    'nullable': True,
#    'defaultValue': None,
#    'modelName': 'DipDirection'},
#   {'name': 'plunge',
#    'type': 'esriFieldTypeSmallInteger',
#    'alias': 'Plunge',
#    'domain': {'type': 'range',
#     'name': 'ShorRange',
#     'description': 'Range for dip',
#     'range': [-90, 90],
#     'mergePolicy': 'esriMPTDefaultValue',
#     'splitPolicy': 'esriSPTDefaultValue'},
#    'editable': True,
#    'nullable': True,
#    'defaultValue': None,
#    'modelName': 'Plunge'},
#   {'name': 'trend',
#    'type': 'esriFieldTypeSmallInteger',
#    'alias': 'Trend',
#    'domain': {'type': 'range',
#     'name': 'ShorStrike',
#     'description': 'Short range strike',
#     'range': [0, 360],
#     'mergePolicy': 'esriMPTDefaultValue',
#     'splitPolicy': 'esriSPTDefaultValue'},
#    'editable': True,
#    'nullable': True,
#    'defaultValue': None,
#    'modelName': 'Trend'},
#   {'name': 'rake',
#    'type': 'esriFieldTypeSmallInteger',
#    'alias': 'Rake',
#    'domain': {'type': 'range',
#     'name': 'ShorRange',
#     'description': 'Range for dip',
#     'range': [-90, 90],
#     'mergePolicy': 'esriMPTDefaultValue',
#     'splitPolicy': 'esriSPTDefaultValue'},
#    'editable': True,
#    'nullable': True,
#    'defaultValue': None,
#    'modelName': 'Rake'},
#   {'name': 'measurement_confidence',
#    'type': 'esriFieldTypeString',
#    'alias': 'Measurement Confidence',
#    'domain': {'type': 'codedValue',
#     'name': 'IDConf',
#     'description': 'Confidence in IDing the litho',
#     'codedValues': [{'name': 'Unspecified', 'code': '1'},
#      {'name': 'Uncertain', 'code': '2'},
#      {'name': 'Fairly Certain', 'code': '3'},
#      {'name': 'Absolute Certainty', 'code': '4'}],
#     'mergePolicy': 'esriMPTDefaultValue',
#     'splitPolicy': 'esriSPTDefaultValue'},
#    'editable': True,
#    'nullable': True,
#    'length': 15,
#    'defaultValue': None,
#    'modelName': 'Measurement_Confidence'},
#   {'name': 'method_measurement',
#    'type': 'esriFieldTypeString',
#    'alias': 'Measurement Method',
#    'domain': {'type': 'codedValue',
#     'name': 'MeasureMeth',
#     'description': 'How was the structure Measured',
#     'codedValues': [{'name': 'Unspecified', 'code': '1'},
#      {'name': 'Direct Measurement', 'code': '2'},
#      {'name': 'Compass Sight', 'code': '3'},
#      {'name': 'Average of Multiple Measurements', 'code': '4'},
#      {'name': 'Photo Interpretation', 'code': '5'},
#      {'name': '3pt Problem Solution', 'code': '6'}],
#     'mergePolicy': 'esriMPTDefaultValue',
#     'splitPolicy': 'esriSPTDefaultValue'},
#    'editable': True,
#    'nullable': True,
#    'length': 25,
#    'defaultValue': None,
#    'modelName': 'Method_Measurement'},
#   {'name': 'globalid',
#    'type': 'esriFieldTypeGlobalID',
#    'alias': 'GlobalID',
#    'domain': None,
#    'editable': False,
#    'nullable': False,
#    'length': 38,
#    'defaultValue': None,
#    'modelName': 'GlobalID'},
#   {'name': 'comments',
#    'type': 'esriFieldTypeString',
#    'alias': 'Comments',
#    'domain': None,
#    'editable': True,
#    'nullable': True,
#    'length': 100,
#    'defaultValue': None,
#    'modelName': 'Comments'},
#   {'name': 'photo',
#    'type': 'esriFieldTypeRaster',
#    'alias': 'Photo',
#    'domain': None,
#    'editable': True,
#    'nullable': True,
#    'defaultValue': None,
#    'modelName': 'Photo'}],
#  'geometryField': {'name': 'shape',
#   'type': 'esriFieldTypeGeometry',
#   'alias': 'SHAPE',
#   'domain': None,
#   'editable': True,
#   'nullable': True,
#   'defaultValue': None,
#   'modelName': 'SHAPE'},
#  'indexes': [{'name': 'r50_sde_rowid_uk',
#    'fields': 'objectid',
#    'isAscending': True,
#    'isUnique': True,
#    'description': ''},
#   {'name': 'sde_rix_9',
#    'fields': 'photo',
#    'isAscending': True,
#    'isUnique': True,
#    'description': ''},
#   {'name': 'uuid_50',
#    'fields': 'globalid',
#    'isAscending': True,
#    'isUnique': False,
#    'description': ''},
#   {'name': 'a13_ix1',
#    'fields': 'shape',
#    'isAscending': True,
#    'isUnique': True,
#    'description': ''}],
#  'dateFieldsTimeReference': {'timeZone': 'UTC',
#   'respectsDaylightSaving': False},
#  'types': [{'id': '1',
#    'name': '1',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Anticline',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '1',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '7',
#    'name': '7',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Antiform',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '7',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '12',
#    'name': '12',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Asymmetrical Anticline',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '12',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '13',
#    'name': '13',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Asymmetrical Syncline',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '13',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '20',
#    'name': '20',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Fold Axis, fodl type unknown or indeterminable',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '20',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '15',
#    'name': '15',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Fold Hinge Length Exposed at surface',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '15',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '16',
#    'name': '16',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Hinge Line',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '16',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '14',
#    'name': '14',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Monocline',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '14',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '5',
#    'name': '5',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Monocline, Anticlinal Bend',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '5',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '6',
#    'name': '6',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Monocline, Synclinal Bend',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '6',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '3',
#    'name': '3',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Overturned Anticline',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '3',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '9',
#    'name': '9',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Overturned Antiform',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '9',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '4',
#    'name': '4',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Overturned Syncline',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '4',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '10',
#    'name': '10',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Overturned Synform',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '10',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '2',
#    'name': '2',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Syncline',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '2',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '8',
#    'name': '8',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Synform',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '8',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]},
#   {'id': '21',
#    'name': '21',
#    'domains': {'fold_type': {'type': 'inherited'},
#     'classification_confidence': {'type': 'inherited'},
#     'strike': {'type': 'inherited'},
#     'dip': {'type': 'inherited'},
#     'dipdirection': {'type': 'inherited'},
#     'plunge': {'type': 'inherited'},
#     'trend': {'type': 'inherited'},
#     'rake': {'type': 'inherited'},
#     'measurement_confidence': {'type': 'inherited'},
#     'method_measurement': {'type': 'inherited'}},
#    'templates': [{'name': 'Trace of Axial Surface',
#      'description': '',
#      'prototype': {'attributes': {'emp_id': None,
#        'comments': None,
#        'fold_type': '21',
#        'classification_confidence': None,
#        'strike': None,
#        'dip': None,
#        'dipdirection': None,
#        'plunge': None,
#        'trend': None,
#        'rake': None,
#        'measurement_confidence': None,
#        'method_measurement': None,
#        'photo': None}},
#      'drawingTool': 'esriFeatureEditToolPoint'}]}],
#  'templates': [],
#  'maxRecordCount': 1000,
#  'supportedQueryFormats': 'JSON, geoJSON',
#  'capabilities': 'Query,Create,Update,Delete,Uploads,Editing',
#  'useStandardizedQueries': True,
#  'standardMaxRecordCount': 32000,
#  'tileMaxRecordCount': 8000,
#  'maxRecordCountFactor': 1}

# %%
metadata['editFieldsInfo']

# %%
url = "https://services6.arcgis.com/bKYAIlQgwHslVRaK/ArcGIS/rest/services/CasesByRegion_ViewLayer/FeatureServer/0"

# %%
metadata = requests.get(url, params=dict(f="pjson")).json()
metadata
# Out:
# {'currentVersion': 10.81,
#  'id': 0,
#  'name': 'CasesByRegion',
#  'type': 'Feature Layer',
#  'serviceItemId': '2d657302ce9342e39ba5d76cde644ee6',
#  'cacheMaxAge': 300,
#  'isView': True,
#  'isUpdatableView': True,
#  'sourceSchemaChangesAllowed': True,
#  'displayField': 'Region_Name_AR',
#  'description': '',
#  'copyrightText': '',
#  'defaultVisibility': True,
#  'editingInfo': {'lastEditDate': 1655549364754},
#  'multiScaleGeometryInfo': {'levels': [1, 3, 5, 7, 9, 11, 13, 15],
#   'generalizationType': 'DP'},
#  'relationships': [],
#  'isDataVersioned': False,
#  'hasContingentValuesDefinition': False,
#  'supportsAppend': True,
#  'supportsCalculate': True,
#  'supportsASyncCalculate': True,
#  'supportsTruncate': False,
#  'supportsAttachmentsByUploadId': True,
#  'supportsAttachmentsResizing': True,
#  'supportsRollbackOnFailureParameter': True,
#  'supportsStatistics': True,
#  'supportsExceedsLimitStatistics': True,
#  'supportsAdvancedQueries': True,
#  'supportsValidateSql': True,
#  'supportsCoordinatesQuantization': True,
#  'supportsLayerOverrides': True,
#  'supportsTilesAndBasicQueriesMode': True,
#  'supportsFieldDescriptionProperty': True,
#  'supportsQuantizationEditMode': True,
#  'supportsApplyEditsWithGlobalIds': True,
#  'supportsMultiScaleGeometry': True,
#  'supportsReturningQueryGeometry': True,
#  'hasGeometryProperties': True,
#  'geometryProperties': {'shapeAreaFieldName': 'Shape__Area',
#   'shapeLengthFieldName': 'Shape__Length',
#   'units': 'esriMeters'},
#  'advancedQueryCapabilities': {'supportsPagination': True,
#   'supportsQueryAttachmentsCountOnly': True,
#   'supportsPaginationOnAggregatedQueries': True,
#   'supportsQueryRelatedPagination': True,
#   'supportsQueryWithDistance': True,
#   'supportsReturningQueryExtent': True,
#   'supportsStatistics': True,
#   'supportsOrderBy': True,
#   'supportsDistinct': True,
#   'supportsQueryWithResultType': True,
#   'supportsSqlExpression': True,
#   'supportsAdvancedQueryRelated': True,
#   'supportsCountDistinct': True,
#   'supportsPercentileStatistics': True,
#   'supportsSpatialAggregationStatistics': True,
#   'supportedSpatialAggregationStatistics': ['EnvelopeAggregate',
#    'CentroidAggregate',
#    'ConvexHullAggregate'],
#   'supportsLod': True,
#   'supportsQueryWithLodSR': False,
#   'supportedLodTypes': ['geohash'],
#   'supportsReturningGeometryCentroid': True,
#   'supportsReturningGeometryProperties': True,
#   'supportsQueryWithDatumTransformation': True,
#   'supportsHavingClause': True,
#   'supportsOutFieldSQLExpression': True,
#   'supportsMaxRecordCountFactor': True,
#   'supportsTopFeaturesQuery': True,
#   'supportsDisjointSpatialRel': True,
#   'supportsQueryWithCacheHint': True,
#   'supportedOperationsWithCacheHint': ['query',
#    'queryTopFilter',
#    'queryAnalytics',
#    'queryAttachments',
#    'queryRelated'],
#   'supportsQueryAnalytic': True,
#   'supportsDefaultSR': True},
#  'advancedQueryAnalyticCapabilities': {'supportsLinearRegression': True,
#   'supportsAsync': True,
#   'supportsPercentileAnalytic': True},
#  'advancedEditingCapabilities': {'supportedSqlFormatsInCalculate': ['standard'],
#   'supportsAsyncApplyEdits': True,
#   'supportsReturnEditResults': True},
#  'infoInEstimates': ['extent', 'count'],
#  'useStandardizedQueries': True,
#  'geometryType': 'esriGeometryPolygon',
#  'minScale': 0,
#  'maxScale': 0,
#  'extent': {'xmin': 3848437.875599999,
#   'ymin': 1848716.3255000005,
#   'xmax': 6196784.987500001,
#   'ymax': 3783537.5135999992,
#   'spatialReference': {'wkid': 102100, 'latestWkid': 3857}},
#  'drawingInfo': {'renderer': {'type': 'simple',
#    'symbol': {'type': 'esriSFS',
#     'style': 'esriSFSSolid',
#     'color': [221, 209, 252, 255],
#     'outline': {'type': 'esriSLS',
#      'style': 'esriSLSSolid',
#      'color': [110, 110, 110, 255],
#      'width': 0.7}}},
#   'scaleSymbols': True,
#   'transparency': 0,
#   'labelingInfo': None},
#  'allowGeometryUpdates': False,
#  'hasAttachments': False,
#  'viewSourceHasAttachments': False,
#  'htmlPopupType': 'esriServerHTMLPopupTypeAsHTMLText',
#  'hasMetadata': True,
#  'hasM': False,
#  'hasZ': False,
#  'objectIdField': 'OBJECTID',
#  'uniqueIdField': {'name': 'OBJECTID', 'isSystemMaintained': True},
#  'globalIdField': 'GlobalID',
#  'typeIdField': '',
#  'fields': [{'name': 'OBJECTID',
#    'type': 'esriFieldTypeOID',
#    'alias': 'OBJECTID',
#    'sqlType': 'sqlTypeOther',
#    'nullable': False,
#    'editable': False,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'REG_CODE',
#    'type': 'esriFieldTypeString',
#    'alias': 'REG_CODE',
#    'sqlType': 'sqlTypeOther',
#    'length': 255,
#    'nullable': True,
#    'editable': True,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Region_Name_AR',
#    'type': 'esriFieldTypeString',
#    'alias': 'Region_Name_AR',
#    'sqlType': 'sqlTypeOther',
#    'length': 254,
#    'nullable': True,
#    'editable': True,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'region_name_en',
#    'type': 'esriFieldTypeString',
#    'alias': 'region_name_en',
#    'sqlType': 'sqlTypeOther',
#    'length': 254,
#    'nullable': True,
#    'editable': True,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'GovCounts',
#    'type': 'esriFieldTypeString',
#    'alias': 'GovCounts',
#    'sqlType': 'sqlTypeOther',
#    'length': 10,
#    'nullable': True,
#    'editable': True,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'TotalConfirmed',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'TotalConfirmed',
#    'sqlType': 'sqlTypeOther',
#    'nullable': True,
#    'editable': True,
#    'domain': None,
#    'defaultValue': 0},
#   {'name': 'TotalDeaths',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'TotalDeaths',
#    'sqlType': 'sqlTypeOther',
#    'nullable': True,
#    'editable': True,
#    'domain': None,
#    'defaultValue': 0},
#   {'name': 'TotalRecovered',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'TotalRecovered',
#    'sqlType': 'sqlTypeOther',
#    'nullable': True,
#    'editable': True,
#    'domain': None,
#    'defaultValue': 0},
#   {'name': 'TotalActive',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'TotalActive',
#    'sqlType': 'sqlTypeOther',
#    'nullable': True,
#    'editable': True,
#    'domain': None,
#    'defaultValue': 0},
#   {'name': 'TotalCalculatedRecords',
#    'type': 'esriFieldTypeSmallInteger',
#    'alias': 'TotalCalculatedRecords',
#    'sqlType': 'sqlTypeOther',
#    'nullable': True,
#    'editable': True,
#    'domain': None,
#    'defaultValue': 0},
#   {'name': 'GlobalID',
#    'type': 'esriFieldTypeGlobalID',
#    'alias': '',
#    'sqlType': 'sqlTypeOther',
#    'length': 38,
#    'nullable': False,
#    'editable': False,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Shape__Area',
#    'type': 'esriFieldTypeDouble',
#    'alias': 'Shape__Area',
#    'sqlType': 'sqlTypeDouble',
#    'nullable': True,
#    'editable': False,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Shape__Length',
#    'type': 'esriFieldTypeDouble',
#    'alias': 'Shape__Length',
#    'sqlType': 'sqlTypeDouble',
#    'nullable': True,
#    'editable': False,
#    'domain': None,
#    'defaultValue': None}],
#  'indexes': [{'name': 'PK__CASESBYR__F4B70D85BFDD16B1',
#    'fields': 'OBJECTID',
#    'isAscending': True,
#    'isUnique': True,
#    'description': ''},
#   {'name': 'user_70783.CASESBYREGION_CASESBYREGION_Shape_sidx',
#    'fields': 'Shape',
#    'isAscending': True,
#    'isUnique': False,
#    'description': ''},
#   {'name': 'I3REG_CODE',
#    'fields': 'REG_CODE',
#    'isAscending': True,
#    'isUnique': False,
#    'description': ''},
#   {'name': 'Shape__Area_Index',
#    'fields': 'Shape__Area',
#    'isAscending': True,
#    'isUnique': False,
#    'description': ''},
#   {'name': 'Shape__Length_Index',
#    'fields': 'Shape__Length',
#    'isAscending': True,
#    'isUnique': False,
#    'description': ''},
#   {'name': 'GlobalID_idx',
#    'fields': 'GlobalID',
#    'isAscending': True,
#    'isUnique': True,
#    'description': ''},
#   {'name': 'Region_Name_AR_Index',
#    'fields': 'Region_Name_AR',
#    'isAscending': True,
#    'isUnique': False,
#    'description': 'Region_Name_AR_Index'}],
#  'dateFieldsTimeReference': {'timeZone': 'UTC',
#   'respectsDaylightSaving': False},
#  'preferredTimeReference': None,
#  'types': [],
#  'templates': [{'name': 'CasesByRegion',
#    'description': '',
#    'drawingTool': 'esriFeatureEditToolPolygon',
#    'prototype': {'attributes': {'TotalActive': 0,
#      'TotalCalculatedRecords': 0,
#      'REG_CODE': None,
#      'Region_Name_AR': None,
#      'region_name_en': None,
#      'GovCounts': None,
#      'TotalConfirmed': 0,
#      'TotalDeaths': 0,
#      'TotalRecovered': 0}}}],
#  'supportedQueryFormats': 'JSON, geoJSON, PBF',
#  'supportedAppendFormats': 'sqlite,gpkg,shapefile,filegdb,featureCollection,geojson,csv,excel',
#  'supportedExportFormats': 'csv,shapefile,sqlite,gpkg,filegdb,featureCollection,geojson,excel',
#  'supportedContingentValuesFormats': 'JSON, PBF',
#  'supportedSyncDataOptions': 4,
#  'hasStaticData': True,
#  'maxRecordCount': 2000,
#  'standardMaxRecordCount': 4000,
#  'standardMaxRecordCountNoGeometry': 32000,
#  'tileMaxRecordCount': 4000,
#  'maxRecordCountFactor': 1,
#  'capabilities': 'Query'}

# %%
metadata['editingInfo']
# Out:
# {'lastEditDate': 1655549364754}
